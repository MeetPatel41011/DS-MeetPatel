# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#         Name   Age              City
# 0       John    25          New York
# 1       Mary    30       Los Angeles
# 2      David    40           Chicago
# 3   Samantha    28     San Francisco
# 4        Amy    35             Miami
# 5       John    25          New York
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 8       John    25          New York
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 11     David    40           Chicago
# 12      John    25          New York
# 13      Mary    30       Los Angeles
# 14      Adam    31            Austin
# 15      John    25          New York
# 16       Tom    36      Philadelphia
# 17  Samantha    28     San Francisco
# 18      John    25          New York
# 19      Kate    26   Washington D.C.

# %%
df.drop_duplicates()
# Out:
#         Name   Age              City
# 0       John    25          New York
# 1       Mary    30       Los Angeles
# 2      David    40           Chicago
# 3   Samantha    28     San Francisco
# 4        Amy    35             Miami
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 14      Adam    31            Austin
# 16       Tom    36      Philadelphia
# 19      Kate    26   Washington D.C.

# %%
df.drop_duplicates(keep='first')
# Out:
#         Name   Age              City
# 0       John    25          New York
# 1       Mary    30       Los Angeles
# 2      David    40           Chicago
# 3   Samantha    28     San Francisco
# 4        Amy    35             Miami
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 14      Adam    31            Austin
# 16       Tom    36      Philadelphia
# 19      Kate    26   Washington D.C.

# %%
df.drop_duplicates( keep='last')
# Out:
#         Name   Age              City
# 4        Amy    35             Miami
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 11     David    40           Chicago
# 13      Mary    30       Los Angeles
# 14      Adam    31            Austin
# 16       Tom    36      Philadelphia
# 17  Samantha    28     San Francisco
# 18      John    25          New York
# 19      Kate    26   Washington D.C.

# %%
df.drop_duplicates(keep=False)
# Out:
#       Name   Age              City
# 4      Amy    35             Miami
# 6   Steven    32           Seattle
# 7    Sarah    27           Houston
# 9     Alex    29            Boston
# 10   Emily    33            Denver
# 14    Adam    31            Austin
# 16     Tom    36      Philadelphia
# 19    Kate    26   Washington D.C.

# %%
df.drop_duplicates(keep='first')
# Out:
#         Name   Age              City
# 0       John    25          New York
# 1       Mary    30       Los Angeles
# 2      David    40           Chicago
# 3   Samantha    28     San Francisco
# 4        Amy    35             Miami
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 14      Adam    31            Austin
# 16       Tom    36      Philadelphia
# 19      Kate    26   Washington D.C.

# %%
df.drop_duplicates(keep='last')
# Out:
#         Name   Age              City
# 4        Amy    35             Miami
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 11     David    40           Chicago
# 13      Mary    30       Los Angeles
# 14      Adam    31            Austin
# 16       Tom    36      Philadelphia
# 17  Samantha    28     San Francisco
# 18      John    25          New York
# 19      Kate    26   Washington D.C.

# %%
df.drop_duplicates(subset='Age', keep="first")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.drop_duplicates(subset='Age', keep="first")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6672, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6670 inplace = validate_bool_kwarg(inplace, "inplace")
#    6671 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6672 duplicated = self.duplicated(subset, keep=keep)
#    6674 result = self[-duplicated]
#    6675 if ignore_index:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6806, in DataFrame.duplicated(self, subset, keep)
#    6804 diff = set(subset) - set(self.columns)
#    6805 if diff:
# -> 6806     raise KeyError(Index(diff))
#    6808 if len(subset) == 1 and self.columns.is_unique:
#    6809     # GH#45236 This is faster than get_group_index below
#    6810     result = self[subset[0]].duplicated(keep)
#
# KeyError: Index(['Age'], dtype='object')

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         Name   Age              City
# 0       John    25          New York
# 1       Mary    30       Los Angeles
# 2      David    40           Chicago
# 3   Samantha    28     San Francisco
# 4        Amy    35             Miami
# 6     Steven    32           Seattle
# 7      Sarah    27           Houston
# 9       Alex    29            Boston
# 10     Emily    33            Denver
# 14      Adam    31            Austin
# 16       Tom    36      Philadelphia
# 19      Kate    26   Washington D.C.
