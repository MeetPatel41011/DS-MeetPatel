# %%
import missingno as msno
import pandas as pd

# %%
df = pd.read_csv("MissingMigrantsProject.csv", encoding='latin-1') #data src: https://www.kaggle.com/datasets/jmataya/missingmigrants
df
# Out:
#           id     cause_of_death             region_origin  \
# 0          1  Presumed drowning               Middle East
# 1          3    Fell from train  Central America & Mexico
# 2          4  Presumed drowning               Middle East
# 3          6           Drowning                      MENA
# 4          7   Vehicle accident           South East Asia
# ...      ...                ...                       ...
# 2415  184746           Drowning  Central America & Mexico
# 2416  184747     Train accident  Central America & Mexico
# 2417  184748                NaN  Central America & Mexico
# 2418  184749     Train accident  Central America & Mexico
# 2419  184750        Dehydration        Sub-Saharan Africa
#
#      affected_nationality  missing  dead               incident_region  \
# 0                    Iraq      1.0   1.0                 Mediterranean
# 1                Honduras      NaN   1.0  Central America incl. Mexico
# ...

# %%
df.isna().sum()
# Out:
# id                         0
# cause_of_death           203
# region_origin            443
# affected_nationality    1575
# missing                 2149
# dead                     102
# incident_region           10
# date                       9
# source                     7
# reliability              324
# lat                        4
# lon                        4
# dtype: int64

# %%
df.iloc[:30,:]['missing']
# Out:
# 0      1.0
# 1      NaN
# 2      NaN
# 3      6.0
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      0.0
# 9      NaN
# 10     NaN
# 11     7.0
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18    32.0
# 19     4.0
# 20     2.0
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     1.0
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# Name: missing, dtype: float64

# %%
df.ffill(axis = 0)
# Out:
#           id     cause_of_death             region_origin  \
# 0          1  Presumed drowning               Middle East
# 1          3    Fell from train  Central America & Mexico
# 2          4  Presumed drowning               Middle East
# 3          6           Drowning                      MENA
# 4          7   Vehicle accident           South East Asia
# ...      ...                ...                       ...
# 2415  184746           Drowning  Central America & Mexico
# 2416  184747     Train accident  Central America & Mexico
# 2417  184748     Train accident  Central America & Mexico
# 2418  184749     Train accident  Central America & Mexico
# 2419  184750        Dehydration        Sub-Saharan Africa
#
#      affected_nationality  missing  dead               incident_region  \
# 0                    Iraq      1.0   1.0                 Mediterranean
# 1                Honduras      1.0   1.0  Central America incl. Mexico
# ...

# %%
df.iloc[:30,:]['missing']
# Out:
# 0      1.0
# 1      NaN
# 2      NaN
# 3      6.0
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      0.0
# 9      NaN
# 10     NaN
# 11     7.0
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18    32.0
# 19     4.0
# 20     2.0
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     1.0
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# Name: missing, dtype: float64

# %%
df.isna().sum()
# Out:
# id                         0
# cause_of_death           203
# region_origin            443
# affected_nationality    1575
# missing                 2149
# dead                     102
# incident_region           10
# date                       9
# source                     7
# reliability              324
# lat                        4
# lon                        4
# dtype: int64

# %%
df = pd.read_csv("MissingMigrantsProject.csv", encoding='latin-1') #data src: https://www.kaggle.com/datasets/jmataya/missingmigrants
df
# Out:
#           id     cause_of_death             region_origin  \
# 0          1  Presumed drowning               Middle East
# 1          3    Fell from train  Central America & Mexico
# 2          4  Presumed drowning               Middle East
# 3          6           Drowning                      MENA
# 4          7   Vehicle accident           South East Asia
# ...      ...                ...                       ...
# 2415  184746           Drowning  Central America & Mexico
# 2416  184747     Train accident  Central America & Mexico
# 2417  184748                NaN  Central America & Mexico
# 2418  184749     Train accident  Central America & Mexico
# 2419  184750        Dehydration        Sub-Saharan Africa
#
#      affected_nationality  missing  dead               incident_region  \
# 0                    Iraq      1.0   1.0                 Mediterranean
# 1                Honduras      NaN   1.0  Central America incl. Mexico
# ...

# %%
df = df.ffill(axis = 1)

# %%
df
# Out:
#           id     cause_of_death             region_origin  \
# 0          1  Presumed drowning               Middle East
# 1          3    Fell from train  Central America & Mexico
# 2          4  Presumed drowning               Middle East
# 3          6           Drowning                      MENA
# 4          7   Vehicle accident           South East Asia
# ...      ...                ...                       ...
# 2415  184746           Drowning  Central America & Mexico
# 2416  184747     Train accident  Central America & Mexico
# 2417  184748             184748  Central America & Mexico
# 2418  184749     Train accident  Central America & Mexico
# 2419  184750        Dehydration        Sub-Saharan Africa
#
#           affected_nationality                   missing  dead  \
# 0                         Iraq                       1.0   1.0
# 1                     Honduras                  Honduras   1.0
# 2                  Middle East               Middle East   1.0
# ...

# %%
df.isna().sum()
# Out:
# id                      0
# cause_of_death          0
# region_origin           0
# affected_nationality    0
# missing                 0
# dead                    0
# incident_region         0
# date                    0
# source                  0
# reliability             0
# lat                     0
# lon                     0
# dtype: int64

# %%
df = pd.read_csv("MissingMigrantsProject.csv", encoding='latin-1') #data src: https://www.kaggle.com/datasets/jmataya/missingmigrants
df
# Out:
#           id     cause_of_death             region_origin  \
# 0          1  Presumed drowning               Middle East
# 1          3    Fell from train  Central America & Mexico
# 2          4  Presumed drowning               Middle East
# 3          6           Drowning                      MENA
# 4          7   Vehicle accident           South East Asia
# ...      ...                ...                       ...
# 2415  184746           Drowning  Central America & Mexico
# 2416  184747     Train accident  Central America & Mexico
# 2417  184748                NaN  Central America & Mexico
# 2418  184749     Train accident  Central America & Mexico
# 2419  184750        Dehydration        Sub-Saharan Africa
#
#      affected_nationality  missing  dead               incident_region  \
# 0                    Iraq      1.0   1.0                 Mediterranean
# 1                Honduras      NaN   1.0  Central America incl. Mexico
# ...

# %%
df['missing'] = df['missing'].ffill(axis = 0)

# %%
df.iloc[:30,:]['missing']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      6.0
# 4      6.0
# 5      6.0
# 6      6.0
# 7      6.0
# 8      0.0
# 9      0.0
# 10     0.0
# 11     7.0
# 12     7.0
# 13     7.0
# 14     7.0
# 15     7.0
# 16     7.0
# 17     7.0
# 18    32.0
# 19     4.0
# 20     2.0
# 21     2.0
# 22     2.0
# 23     2.0
# 24     2.0
# 25     1.0
# 26     1.0
# 27     1.0
# 28     1.0
# 29     1.0
# Name: missing, dtype: float64

# %%
df.isna().sum()
# Out:
# id                         0
# cause_of_death           203
# region_origin            443
# affected_nationality    1575
# missing                    0
# dead                     102
# incident_region           10
# date                       9
# source                     7
# reliability              324
# lat                        4
# lon                        4
# dtype: int64

# %%
df.loc[0:30, ['region_origin','affected_nationality']]
# Out:
#                region_origin affected_nationality
# 0                Middle East                 Iraq
# 1   Central America & Mexico             Honduras
# 2                Middle East                  NaN
# 3                       MENA                  NaN
# 4            South East Asia             Cambodia
# 5                       MENA                  NaN
# 6                       MENA                  NaN
# 7                       MENA                  NaN
# 8                        NaN                  NaN
# 9                       MENA                Syria
# 10                      MENA                 Iran
# 11                South Asia          Afghanistan
# 12   Middle East/ South Asia                  NaN
# 13                       NaN          Afghanistan
# 14                South Asia               Afghan
# 15                       NaN                  NaN
# 16        Sub-Saharan Africa      Likely Comorian
# 17   Middle East/ South Asia                  NaN
# ...

# %%
df.loc[:, ['region_origin','affected_nationality']] = df.loc[:, ['region_origin','affected_nationality']].ffill(axis = 1)

# %%
df.loc[0:30, ['region_origin','affected_nationality']]
# Out:
#                region_origin     affected_nationality
# 0                Middle East                     Iraq
# 1   Central America & Mexico                 Honduras
# 2                Middle East              Middle East
# 3                       MENA                     MENA
# 4            South East Asia                 Cambodia
# 5                       MENA                     MENA
# 6                       MENA                     MENA
# 7                       MENA                     MENA
# 8                        NaN                      NaN
# 9                       MENA                    Syria
# 10                      MENA                     Iran
# 11                South Asia              Afghanistan
# 12   Middle East/ South Asia  Middle East/ South Asia
# 13                       NaN              Afghanistan
# 14                South Asia                   Afghan
# 15                       NaN                      NaN
# ...
