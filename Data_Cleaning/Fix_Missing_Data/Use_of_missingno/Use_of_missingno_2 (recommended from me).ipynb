# %%
import missingno as msno
import pandas as pd

# %%
df = pd.read_csv("NFL Play by Play 2009-2016 (v3).csv") #data src: https://www.kaggle.com/code/rtatman/data-cleaning-challenge-handling-missing-values/input?select=NFL+Play+by+Play+2009-2016+%28v3%29.csvdf
df
# Out:
# C:\Users\Meet Patel\AppData\Local\Temp\ipykernel_14988\2648580269.py:1: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("NFL Play by Play 2009-2016 (v3).csv") #data src: https://www.kaggle.com/code/rtatman/data-cleaning-challenge-handling-missing-values/input?select=NFL+Play+by+Play+2009-2016+%28v3%29.csvdf
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 362442  2017-01-01  2017010102     20    4   1.0  00:22          1      22.0
# 362443  2017-01-01  2017010102     20    4   NaN  00:13          1      13.0
# 362444  2017-01-01  2017010102     21    4   NaN  00:13          1      13.0
# 362445  2017-01-01  2017010102     21    4   1.0  00:12          1      12.0
# 362446  2017-01-01  2017010102     21    4   NaN  00:00          0       0.0
#
#         PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0                0.0         TEN  ...       NaN     0.485675     0.514325
# 1                7.0         PIT  ...  1.146076     0.546433     0.453567
# 2               37.0         PIT  ...       NaN     0.551088     0.448912
# 3               41.0         PIT  ... -5.031425     0.510793     0.489207
# 4                8.0         PIT  ...       NaN     0.461217     0.538783
# ...              ...         ...  ...       ...          ...          ...
# 362442           6.0          GB  ...  0.000000     0.051901     0.948099
# 362443           9.0          GB  ...       NaN     0.093435     0.906565
# 362444           0.0         DET  ...       NaN     0.034069     0.965931
# 362445           1.0         DET  ...       NaN     0.035708     0.964292
# 362446          12.0         DET  ...       NaN     0.000000     1.000000
#
#         Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  \
# 0           0.546433      0.453567  0.485675  0.060758       NaN       NaN
# 1           0.551088      0.448912  0.546433  0.004655 -0.032244  0.036899
# 2           0.510793      0.489207  0.551088 -0.040295       NaN       NaN
# 3           0.461217      0.538783  0.510793 -0.049576  0.106663 -0.156239
# 4           0.558929      0.441071  0.461217  0.097712       NaN       NaN
# ...              ...           ...       ...       ...       ...       ...
# 362442      0.093435      0.906565  0.051901  0.041534  0.041534  0.000000
# 362443      0.034069      0.965931  0.093435 -0.059366       NaN       NaN
# 362444      0.035708      0.964292  0.965931 -0.001639       NaN       NaN
# 362445      0.000000      1.000000  0.964292  0.035708       NaN       NaN
# 362446      0.000000      1.000000  0.934245  0.000000       NaN       NaN
#
#         Season
# 0         2009
# 1         2009
# 2         2009
# 3         2009
# 4         2009
# ...        ...
# 362442    2016
# 362443    2016
# 362444    2016
# 362445    2016
# 362446    2016
#
# [362447 rows x 102 columns]

# %%
#Method - 2 - To analysis missing data

msno.matrix(df) #difference between above bar graph and this matrix plot is, Matrix Plot has benefit that you can view how that missing data is distributed in the dataframe.
#each and every line represent a column, grey part represent as data and white part represent as missing data 
#we can see that some columns have just few data and some have not that much too. (we will definitely remove that all columns.)
#we can't see column name at their represented line in below graph, Coz if dataset have 50 columns than only msno matrix can show column names.(here 120 column, so we will divide dataset with respect to 'columns')


#-----IMPORTANT-----
# On the right side of the plot is a sparkline that ranges from 0 on the left to the total number of columns in the dataframe on the right.
# When a row has a value in each column, the line will be at the maximum right position. As missing values start to increase within that row the line will move towards the left.
# Look at here, 88 means, a row contains 88 values which is highest among all rows and a row is here which have 43 values which is lowest among all rows.
# Out:
# <Axes: >

# %%
df1 = df.iloc[:,:50]
df1
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 362442  2017-01-01  2017010102     20    4   1.0  00:22          1      22.0
# 362443  2017-01-01  2017010102     20    4   NaN  00:13          1      13.0
# 362444  2017-01-01  2017010102     21    4   NaN  00:13          1      13.0
# 362445  2017-01-01  2017010102     21    4   1.0  00:12          1      12.0
# 362446  2017-01-01  2017010102     21    4   NaN  00:00          0       0.0
#
#         PlayTimeDiff SideofField  ...  Interceptor    Rusher   Rusher_ID  \
# 0                0.0         TEN  ...          NaN       NaN        None
# 1                7.0         PIT  ...          NaN       NaN        None
# 2               37.0         PIT  ...          NaN  W.Parker  00-0022250
# 3               41.0         PIT  ...          NaN       NaN        None
# 4                8.0         PIT  ...          NaN       NaN        None
# ...              ...         ...  ...          ...       ...         ...
# 362442           6.0          GB  ...          NaN       NaN        None
# 362443           9.0          GB  ...          NaN       NaN        None
# 362444           0.0         DET  ...          NaN       NaN        None
# 362445           1.0         DET  ...          NaN       NaN  00-0023459
# 362446          12.0         DET  ...          NaN       NaN        None
#
#         RushAttempt  RunLocation  RunGap   Receiver Receiver_ID Reception  \
# 0                 0          NaN     NaN        NaN        None         0
# 1                 0          NaN     NaN     H.Ward  00-0017162         1
# 2                 1        right     end        NaN        None         0
# 3                 0          NaN     NaN  M.Wallace  00-0026901         0
# 4                 0          NaN     NaN        NaN        None         0
# ...             ...          ...     ...        ...         ...       ...
# 362442            0          NaN     NaN   A.Boldin  00-0022084         1
# 362443            0          NaN     NaN        NaN        None         0
# 362444            0          NaN     NaN        NaN        None         0
# 362445            0          NaN     NaN        NaN        None         0
# 362446            0          NaN     NaN        NaN        None         0
#
#         ReturnResult
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 362442           NaN
# 362443           NaN
# 362444           NaN
# 362445           NaN
# 362446           NaN
#
# [362447 rows x 50 columns]

# %%
msno.matrix(df1) #Look at here at sparkline, 44 means, a row contains 44 values which is highest among all rows and a row is here which have 26 values which is lowest among all rows.

#sparkline values are changed, because we made matrix for 102 columns and now it's for 50 columns
# Out:
# <Axes: >

# %%
df2 = df.iloc[:,50:100]
df2
# Out:
#        Returner BlockingPlayer   Tackler1 Tackler2 FieldGoalResult  \
# 0       S.Logan            NaN  M.Griffin      NaN             NaN
# 1           NaN            NaN     C.Hope      NaN             NaN
# 2           NaN            NaN  S.Tulloch      NaN             NaN
# 3           NaN            NaN        NaN      NaN             NaN
# 4           NaN            NaN        NaN      NaN             NaN
# ...         ...            ...        ...      ...             ...
# 362442      NaN            NaN        NaN      NaN             NaN
# 362443      NaN            NaN        NaN      NaN             NaN
# 362444      NaN            NaN     J.Bell      NaN             NaN
# 362445      NaN            NaN        NaN      NaN             NaN
# 362446      NaN            NaN        NaN      NaN             NaN
#
#         FieldGoalDistance  Fumble RecFumbTeam RecFumbPlayer  Sack  ...  \
# 0                     NaN       0         NaN           NaN     0  ...
# 1                     NaN       0         NaN           NaN     0  ...
# 2                     NaN       0         NaN           NaN     0  ...
# 3                     NaN       0         NaN           NaN     0  ...
# 4                     NaN       0         NaN           NaN     0  ...
# ...                   ...     ...         ...           ...   ...  ...
# 362442                NaN       0         NaN           NaN     0  ...
# 362443                NaN       0         NaN           NaN     0  ...
# 362444                NaN       0         NaN           NaN     0  ...
# 362445                NaN       0         NaN           NaN     0  ...
# 362446                NaN       0         NaN           NaN     0  ...
#
#              EPA    airEPA    yacEPA Home_WP_pre Away_WP_pre Home_WP_post  \
# 0       2.014474       NaN       NaN    0.485675    0.514325     0.546433
# 1       0.077907 -1.068169  1.146076    0.546433    0.453567     0.551088
# 2      -1.402760       NaN       NaN    0.551088    0.448912     0.510793
# 3      -1.712583  3.318841 -5.031425    0.510793    0.489207     0.461217
# 4       2.097796       NaN       NaN    0.461217    0.538783     0.558929
# ...          ...       ...       ...         ...         ...          ...
# 362442  4.620003  4.620003  0.000000    0.051901    0.948099     0.093435
# 362443  0.068885       NaN       NaN    0.093435    0.906565     0.034069
# 362444 -0.692792       NaN       NaN    0.034069    0.965931     0.035708
# 362445  0.000000       NaN       NaN    0.035708    0.964292     0.000000
# 362446  0.000000       NaN       NaN    0.000000    1.000000     0.000000
#
#         Away_WP_post  Win_Prob       WPA    airWPA
# 0           0.453567  0.485675  0.060758       NaN
# 1           0.448912  0.546433  0.004655 -0.032244
# 2           0.489207  0.551088 -0.040295       NaN
# 3           0.538783  0.510793 -0.049576  0.106663
# 4           0.441071  0.461217  0.097712       NaN
# ...              ...       ...       ...       ...
# 362442      0.906565  0.051901  0.041534  0.041534
# 362443      0.965931  0.093435 -0.059366       NaN
# 362444      0.964292  0.965931 -0.001639       NaN
# 362445      1.000000  0.964292  0.035708       NaN
# 362446      1.000000  0.934245  0.000000       NaN
#
# [362447 rows x 50 columns]

# %%
msno.matrix(df2)
# Out:
# <Axes: >

# %%
df3 = df.iloc[:,100:150] #it will show only 2 columns, Because total 102 columns are there in Dataframe.
df3
# Out:
#           yacWPA  Season
# 0            NaN    2009
# 1       0.036899    2009
# 2            NaN    2009
# 3      -0.156239    2009
# 4            NaN    2009
# ...          ...     ...
# 362442  0.000000    2016
# 362443       NaN    2016
# 362444       NaN    2016
# 362445       NaN    2016
# 362446       NaN    2016
#
# [362447 rows x 2 columns]

# %%
msno.matrix(df3) #And we will remove columns from dataframe 'df' but we keep df1, df2, df3 as it is because they are for just analytic purpose.
# Out:
# <Axes: >

# %% [markdown]
# # First remove columns which have very less data or nothing in name of data. 😅

# %%
print(df.columns.tolist()) #All columns
# Out:
# ['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'SideofField', 'yrdln', 'yrdline100', 'ydstogo', 'ydsnet', 'GoalToGo', 'FirstDown', 'posteam', 'DefensiveTeam', 'desc', 'PlayAttempted', 'Yards.Gained', 'sp', 'Touchdown', 'ExPointResult', 'TwoPointConv', 'DefTwoPoint', 'Safety', 'Onsidekick', 'PuntResult', 'PlayType', 'Passer', 'Passer_ID', 'PassAttempt', 'PassOutcome', 'PassLength', 'AirYards', 'YardsAfterCatch', 'QBHit', 'PassLocation', 'InterceptionThrown', 'Interceptor', 'Rusher', 'Rusher_ID', 'RushAttempt', 'RunLocation', 'RunGap', 'Receiver', 'Receiver_ID', 'Reception', 'ReturnResult', 'Returner', 'BlockingPlayer', 'Tackler1', 'Tackler2', 'FieldGoalResult', 'FieldGoalDistance', 'Fumble', 'RecFumbTeam', 'RecFumbPlayer', 'Sack', 'Challenge.Replay', 'ChalReplayResult', 'Accepted.Penalty', 'PenalizedTeam', 'PenaltyType', 'PenalizedPlayer', 'Penalty.Yards', 'PosTeamScore', 'DefTeamScore', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'No_Score_Prob', 'Opp_Field_Goal_Prob', 'Opp_Safety_Prob', 'Opp_Touchdown_Prob', 'Field_Goal_Prob', 'Safety_Prob', 'Touchdown_Prob', 'ExPoint_Prob', 'TwoPoint_Prob', 'ExpPts', 'EPA', 'airEPA', 'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post', 'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season']

# %%
del df['ExPointResult'] #let me remove unnecessary columns

# %%
del df['TwoPointConv']

# %%
del df['DefTwoPoint']

# %%
del df['PuntResult']

# %%
del df['Interceptor']

# %%
del df['RunGap']

# %%
del df['ReturnResult']

# %%
del df['Returner']

# %%
del df['BlockingPlayer']

# %%
del df['Tackler2']

# %%
del df['FieldGoalResult']

# %%
del df['FieldGoalDistance']

# %%
del df['RecFumbTeam']

# %%
del df['RecFumbPlayer']

# %%
del df['ChalReplayResult']

# %%
del df['PenalizedTeam']

# %%
del df['PenaltyType']

# %%
del df['PenalizedPlayer']

# %%
del df['airEPA']

# %%
del df['yacEPA']

# %%
del df['airWPA']

# %%
del df['RunLocation']

# %%
del df['Passer']

# %%
del df['PassOutcome']

# %%
del df['PassLength']

# %%
del df['PassLocation']

# %%
del df['Rusher']

# %%
del df['Receiver']

# %%
del df['Tackler1']

# %%
del df['yacWPA']

# %%
print(df.columns.tolist())
# Out:
# ['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder', 'TimeSecs', 'PlayTimeDiff', 'SideofField', 'yrdln', 'yrdline100', 'ydstogo', 'ydsnet', 'GoalToGo', 'FirstDown', 'posteam', 'DefensiveTeam', 'desc', 'PlayAttempted', 'Yards.Gained', 'sp', 'Touchdown', 'Safety', 'Onsidekick', 'PlayType', 'Passer_ID', 'PassAttempt', 'AirYards', 'YardsAfterCatch', 'QBHit', 'InterceptionThrown', 'Rusher_ID', 'RushAttempt', 'Receiver_ID', 'Reception', 'Fumble', 'Sack', 'Challenge.Replay', 'Accepted.Penalty', 'Penalty.Yards', 'PosTeamScore', 'DefTeamScore', 'ScoreDiff', 'AbsScoreDiff', 'HomeTeam', 'AwayTeam', 'Timeout_Indicator', 'Timeout_Team', 'posteam_timeouts_pre', 'HomeTimeouts_Remaining_Pre', 'AwayTimeouts_Remaining_Pre', 'HomeTimeouts_Remaining_Post', 'AwayTimeouts_Remaining_Post', 'No_Score_Prob', 'Opp_Field_Goal_Prob', 'Opp_Safety_Prob', 'Opp_Touchdown_Prob', 'Field_Goal_Prob', 'Safety_Prob', 'Touchdown_Prob', 'ExPoint_Prob', 'TwoPoint_Prob', 'ExpPts', 'EPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post', 'Win_Prob', 'WPA', 'Season']

# %%
df1_new = df.iloc[:,:50]
msno.matrix(df1_new)
# Out:
# <Axes: >

# %%
df2_new = df.iloc[:,50:100]
msno.matrix(df2_new)
# Out:
# <Axes: >

# %% [markdown]
# We removed columns which have very few data (or nothing in name of data 😅), But still here some columns are preset which have missing values but not that much, so we have to contact our client to ask about that column for precise prediction. (If they want to keep that columns in the prediction model, keep them or remove them.)

# %% [markdown]
# ## Here we just remove columns which have many missing values, after this we have to remove rows also if necessary, but we will show this in further.

# %%
df.shape #total columns deduct from 102 to 72
# Out:
# (362447, 72)

# %%
df.to_csv('NFL_clean_data.csv', index=False) #first we convert csv to dataframe to clean the data and by this code we are making a new csv of clean data.

# %%
df_clean = pd.read_csv('NFL_clean_data.csv')
df_clean
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 362442  2017-01-01  2017010102     20    4   1.0  00:22          1      22.0
# 362443  2017-01-01  2017010102     20    4   NaN  00:13          1      13.0
# 362444  2017-01-01  2017010102     21    4   NaN  00:13          1      13.0
# 362445  2017-01-01  2017010102     21    4   1.0  00:12          1      12.0
# 362446  2017-01-01  2017010102     21    4   NaN  00:00          0       0.0
#
#         PlayTimeDiff SideofField  ...  TwoPoint_Prob    ExpPts       EPA  \
# 0                0.0         TEN  ...            0.0  0.323526  2.014474
# 1                7.0         PIT  ...            0.0  2.338000  0.077907
# 2               37.0         PIT  ...            0.0  2.415907 -1.402760
# 3               41.0         PIT  ...            0.0  1.013147 -1.712583
# 4                8.0         PIT  ...            0.0 -0.699436  2.097796
# ...              ...         ...  ...            ...       ...       ...
# 362442           6.0          GB  ...            0.0  2.379997  4.620003
# 362443           9.0          GB  ...            0.0  0.931115  0.068885
# 362444           0.0         DET  ...            0.0  0.692792 -0.692792
# 362445           1.0         DET  ...            0.0  0.000000  0.000000
# 362446          12.0         DET  ...            0.0  0.000000  0.000000
#
#         Home_WP_pre  Away_WP_pre  Home_WP_post Away_WP_post  Win_Prob  \
# 0          0.485675     0.514325      0.546433     0.453567  0.485675
# 1          0.546433     0.453567      0.551088     0.448912  0.546433
# 2          0.551088     0.448912      0.510793     0.489207  0.551088
# 3          0.510793     0.489207      0.461217     0.538783  0.510793
# 4          0.461217     0.538783      0.558929     0.441071  0.461217
# ...             ...          ...           ...          ...       ...
# 362442     0.051901     0.948099      0.093435     0.906565  0.051901
# 362443     0.093435     0.906565      0.034069     0.965931  0.093435
# 362444     0.034069     0.965931      0.035708     0.964292  0.965931
# 362445     0.035708     0.964292      0.000000     1.000000  0.964292
# 362446     0.000000     1.000000      0.000000     1.000000  0.934245
#
#              WPA  Season
# 0       0.060758    2009
# 1       0.004655    2009
# 2      -0.040295    2009
# 3      -0.049576    2009
# 4       0.097712    2009
# ...          ...     ...
# 362442  0.041534    2016
# 362443 -0.059366    2016
# 362444 -0.001639    2016
# 362445  0.035708    2016
# 362446  0.000000    2016
#
# [362447 rows x 72 columns]
